# %%
import os

print(os.listdir())
# Out:
# ['.ipynb_checkpoints', 'banking_collections_dataset.csv', 'EMI Collection.ipynb', 'EMI Collections.py', 'emi_collection_model.pkl', 'requirements.txt', 'Untitled.ipynb']
