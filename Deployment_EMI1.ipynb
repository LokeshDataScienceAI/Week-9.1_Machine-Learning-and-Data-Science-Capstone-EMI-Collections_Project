# %%
import streamlit as st
import pandas as pd
import pickle

model = pickle.load(
    open("emi_collection_model.pkl", "rb")
)

st.title("Smart EMI Collection Prioritization System")
# Out:
# 2026-06-17 16:47:31.913 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-17 16:47:31.916 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-17 16:47:31.919 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()
